# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\karth\Downloads\archive\job_salary_prediction_dataset.csv")
df
# Out:
#                  job_title  experience_years education_level  skills_count  \
# 0              AI Engineer                10        Bachelor             2
# 1             Data Analyst                 5        Bachelor            17
# 2       Frontend Developer                18             PhD             4
# 3         Business Analyst                19             PhD            13
# 4          Product Manager                15        Bachelor             7
# ...                    ...               ...             ...           ...
# 249995   Software Engineer                17             PhD             2
# 249996  Frontend Developer                20             PhD             7
# 249997    Business Analyst                 1        Bachelor            12
# 249998      Data Scientist                 0     High School             2
# 249999        Data Analyst                16         Diploma             2
#
# ...

# %%
df.columns
# Out:
# Index(['job_title', 'experience_years', 'education_level', 'skills_count',
#        'industry', 'company_size', 'location', 'remote_work', 'certifications',
#        'salary'],
#       dtype='object')

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %%
s=df["salary"]
s
# Out:
# 0         109413
# 1          93764
# 2         148123
# 3         189123
# 4         165069
#            ...
# 249995    127791
# 249996    154593
# 249997     75988
# 249998     90467
# 249999    133084
# Name: salary, Length: 250000, dtype: int64

# %%
kurtosis_answer=s.kurtosis()
kurtosis_answer
# Out:
# np.float64(0.15089558099594536)

# %%
if kurtosis_answer<0:
    print("platykurtic")
elif kurtosis_answer>0:
    print("leptokurtic")
else:
    print("mesokurtic")
# Out:
# leptokurtic

# %%
df.isnull().any()
# Out:
# job_title           False
# experience_years    False
# education_level     False
# skills_count        False
# industry            False
# company_size        False
# location            False
# remote_work         False
# certifications      False
# salary              False
# dtype: bool

# %%
import numpy as np
import pandas as pd

# %%
normal_dist = np.random.normal(loc=50,size=100,scale=3)
normal_dist
# Out:
# array([54.81810212, 54.22178268, 52.0919389 , 52.65766028, 49.12048919,
#        49.40177652, 45.77038205, 52.03942135, 47.8418187 , 50.98729078,
#        49.35766757, 48.56140423, 52.11761747, 53.88540617, 51.5221145 ,
#        46.66403303, 52.64924753, 49.19945763, 48.70945645, 52.42049774,
#        53.25864252, 55.39770834, 45.22644244, 51.90461006, 48.60223649,
#        50.18772937, 49.9925826 , 51.88843118, 52.67116514, 43.04411228,
#        45.76746737, 44.92893357, 44.42431207, 48.28057711, 45.7318817 ,
#        50.20717456, 46.79157411, 51.49380887, 52.1824127 , 52.57482339,
#        53.7321106 , 49.08975546, 54.35361084, 48.34177823, 51.97211655,
#        54.24442849, 48.50560906, 49.47367684, 52.87335178, 45.61919444,
#        52.55015066, 49.93514538, 50.25446637, 52.36996971, 54.29596444,
#        52.48625923, 53.02650301, 51.95009296, 48.39325278, 51.45227646,
#        47.88674683, 47.33242109, 52.53744258, 55.35935802, 54.05554593,
# ...

# %%
k=np.array([1000,1500,2000])
k_data=np.concatenate([normal_dist,k])
k_data
# Out:
# array([  54.81810212,   54.22178268,   52.0919389 ,   52.65766028,
#          49.12048919,   49.40177652,   45.77038205,   52.03942135,
#          47.8418187 ,   50.98729078,   49.35766757,   48.56140423,
#          52.11761747,   53.88540617,   51.5221145 ,   46.66403303,
#          52.64924753,   49.19945763,   48.70945645,   52.42049774,
#          53.25864252,   55.39770834,   45.22644244,   51.90461006,
#          48.60223649,   50.18772937,   49.9925826 ,   51.88843118,
#          52.67116514,   43.04411228,   45.76746737,   44.92893357,
#          44.42431207,   48.28057711,   45.7318817 ,   50.20717456,
#          46.79157411,   51.49380887,   52.1824127 ,   52.57482339,
#          53.7321106 ,   49.08975546,   54.35361084,   48.34177823,
#          51.97211655,   54.24442849,   48.50560906,   49.47367684,
#          52.87335178,   45.61919444,   52.55015066,   49.93514538,
#          50.25446637,   52.36996971,   54.29596444,   52.48625923,
# ...

# %%
np.mean(normal_dist)
# Out:
# np.float64(50.449867398528525)

# %%
np.mean(k)
# Out:
# np.float64(1500.0)

# %%
dp=pd.Series("Normal_data",normal_dist)
dp
# Out:
# 54.818102    Normal_data
# 54.221783    Normal_data
# 52.091939    Normal_data
# 52.657660    Normal_data
# 49.120489    Normal_data
#                 ...
# 49.526472    Normal_data
# 50.108299    Normal_data
# 49.240550    Normal_data
# 50.775261    Normal_data
# 48.802474    Normal_data
# Length: 100, dtype: object

# %%
x=pd.DataFrame({"normal_data":normal_dist})
x
# Out:
#     normal_data
# 0     54.818102
# 1     54.221783
# 2     52.091939
# 3     52.657660
# 4     49.120489
# ..          ...
# 95    49.526472
# 96    50.108299
# 97    49.240550
# 98    50.775261
# 99    48.802474
#
# [100 rows x 1 columns]

# %%
y=pd.DataFrame({"Normal_data":k_data})
y
# Out:
#      Normal_data
# 0      54.818102
# 1      54.221783
# 2      52.091939
# 3      52.657660
# 4      49.120489
# ..           ...
# 98     50.775261
# 99     48.802474
# 100  1000.000000
# 101  1500.000000
# 102  2000.000000
#
# [103 rows x 1 columns]

# %%
y.kurt()
# Out:
# Normal_data    40.923717
# dtype: float64

# %%
x.kurt()
# Out:
# normal_data   -0.498975
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
plt.subplot (1,2,1)
sns.histplot(normal_dist,kde=True)
plt.title("Normal Distribution")
plt.subplot(1,2,2)
sns.histplot(k_data,kde=True)
plt.title("k Data")
plt.show()

# %%
from scipy.stats import skew

# %%
skew(normal_dist)
# Out:
# np.float64(-0.3035237334369844)

# %%
skew(k_data)
# Out:
# np.float64(6.234414848862186)

# %%
data=[15000,14500,20000,25000,30000,100000]
A=np.mean(data)
A
# Out:
# np.float64(34083.333333333336)

# %%
AK=np.median(data)
AK
# Out:
# np.float64(22500.0)

# %%
df=pd.DataFrame({"Salary Data":data})
df
# Out:
#    Salary Data
# 0        15000
# 1        14500
# 2        20000
# 3        25000
# 4        30000
# 5       100000

# %%
df.kurt()
# Out:
# Salary Data    5.317673
# dtype: float64

# %%
df.skew()
# Out:
# Salary Data    2.274309
# dtype: float64

# %%
sns.histplot(data,kde=True)
plt.show()

# %%
plt.boxplot(data)
plt.title("Find Outliers")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
